# %%
# Set up the environment
from utils import load_env, create_agent, stream_response, AgentOptions
load_env()

# %% [markdown]
# # Start chatting with your podcast studio team
#
# Understand the kind of things they can do

# %%
producer = create_agent(
    AgentOptions(
        name="Podcast Producer Agent",
        instructions="",
    )
)
